# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import json
import cx_Oracle
import os
import pandas as pd


os.environ['TNS_ADMIN'] = '/home/opc/adj_esportsdb'

# %%
import os

os.environ['PATH']='/home/ubuntu/miniconda3/bin:$PATH'

# %%
# !pip install simplejson
# !pip install dataprep
# !pip install dask
# !pip install pandas_profiling
## install packages
# !pip install -q scikit-learn
# !pip install -U setuptools wheel
# !pip install -U "mxnet<2.0.0"
# !pip install autogluon
# Out:
# Collecting simplejson
#   Downloading simplejson-3.17.6-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.3/130.3 KB 27.0 MB/s eta 0:00:00
# Installing collected packages: simplejson
# Successfully installed simplejson-3.17.6
# WARNING: You are using pip version 22.0.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/home/ubuntu/miniconda3/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: dataprep in /home/ubuntu/miniconda3/lib/python3.7/site-packages (0.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.48 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dataprep) (4.61.2)
# Requirement already satisfied: pandas<2.0,>=1.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dataprep) (1.3.4)
# Requirement already satisfied: python-stdnum<2.0,>=1.16 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dataprep) (1.17)
# Requirement already satisfied: flask_cors<4.0.0,>=3.0.10 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dataprep) (3.0.10)
# Requirement already satisfied: jsonpath-ng<2.0,>=1.5 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dataprep) (1.5.3)
# Requirement already satisfied: numpy<2.0,>=1.21 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dataprep) (1.21.4)
# Requirement already satisfied: dask[array,dataframe,delayed]<2022.0,>=2021.11 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dataprep) (2021.12.0)
# Requirement already satisfied: metaphone<0.7,>=0.6 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dataprep) (0.6)
# Requirement already satisfied: python-crfsuite<0.10.0,>=0.9.7 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dataprep) (0.9.7)
# Requirement already satisfied: jinja2<4,>=3 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dataprep) (3.0.3)
# Requirement already satisfied: varname<0.9.0,>=0.8.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dataprep) (0.8.1)
# Requirement already satisfied: levenshtein<0.17,>=0.16 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dataprep) (0.16.0)
# Requirement already satisfied: nltk<4.0.0,>=3.6.7 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dataprep) (3.6.7)
# Requirement already satisfied: pydantic<2.0,>=1.6 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dataprep) (1.8.2)
# Requirement already satisfied: flask<3,>=2 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dataprep) (2.0.3)
# Requirement already satisfied: aiohttp<4.0,>=3.6 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dataprep) (3.8.1)
# Requirement already satisfied: wordcloud<2.0,>=1.8 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dataprep) (1.8.1)
# Requirement already satisfied: regex<2022.0.0,>=2021.8.3 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dataprep) (2021.11.10)
# Requirement already satisfied: ipywidgets<8.0,>=7.5 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dataprep) (7.6.5)
# Requirement already satisfied: bokeh<3,>=2 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dataprep) (2.4.2)
# Requirement already satisfied: scipy<2,>=1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dataprep) (1.6.3)
# Requirement already satisfied: attrs>=17.3.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from aiohttp<4.0,>=3.6->dataprep) (21.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from aiohttp<4.0,>=3.6->dataprep) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from aiohttp<4.0,>=3.6->dataprep) (4.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from aiohttp<4.0,>=3.6->dataprep) (2.0.12)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from aiohttp<4.0,>=3.6->dataprep) (1.2.0)
# Requirement already satisfied: asynctest==0.13.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from aiohttp<4.0,>=3.6->dataprep) (0.13.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from aiohttp<4.0,>=3.6->dataprep) (1.3.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from aiohttp<4.0,>=3.6->dataprep) (1.7.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from aiohttp<4.0,>=3.6->dataprep) (3.10.0.2)
# Requirement already satisfied: pillow>=7.1.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from bokeh<3,>=2->dataprep) (8.3.2)
# Requirement already satisfied: PyYAML>=3.10 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from bokeh<3,>=2->dataprep) (6.0)
# Requirement already satisfied: tornado>=5.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from bokeh<3,>=2->dataprep) (6.1)
# Requirement already satisfied: packaging>=16.8 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from bokeh<3,>=2->dataprep) (21.3)
# Requirement already satisfied: partd>=0.3.10 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dask[array,dataframe,delayed]<2022.0,>=2021.11->dataprep) (1.2.0)
# Requirement already satisfied: fsspec>=0.6.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dask[array,dataframe,delayed]<2022.0,>=2021.11->dataprep) (0.8.3)
# Requirement already satisfied: cloudpickle>=1.1.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dask[array,dataframe,delayed]<2022.0,>=2021.11->dataprep) (2.0.0)
# Requirement already satisfied: toolz>=0.8.2 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dask[array,dataframe,delayed]<2022.0,>=2021.11->dataprep) (0.11.2)
# Requirement already satisfied: itsdangerous>=2.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from flask<3,>=2->dataprep) (2.1.0)
# Requirement already satisfied: click>=7.1.2 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from flask<3,>=2->dataprep) (8.0.3)
# Requirement already satisfied: Werkzeug>=2.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from flask<3,>=2->dataprep) (2.0.3)
# Requirement already satisfied: Six in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from flask_cors<4.0.0,>=3.0.10->dataprep) (1.16.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from ipywidgets<8.0,>=7.5->dataprep) (1.0.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from ipywidgets<8.0,>=7.5->dataprep) (3.5.2)
# Requirement already satisfied: traitlets>=4.3.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from ipywidgets<8.0,>=7.5->dataprep) (5.1.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from ipywidgets<8.0,>=7.5->dataprep) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from ipywidgets<8.0,>=7.5->dataprep) (6.4.1)
# Requirement already satisfied: nbformat>=4.2.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from ipywidgets<8.0,>=7.5->dataprep) (5.1.3)
# Requirement already satisfied: ipython>=4.0.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from ipywidgets<8.0,>=7.5->dataprep) (7.29.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from jinja2<4,>=3->dataprep) (2.0.1)
# Requirement already satisfied: decorator in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from jsonpath-ng<2.0,>=1.5->dataprep) (5.1.0)
# Requirement already satisfied: ply in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from jsonpath-ng<2.0,>=1.5->dataprep) (3.11)
# Requirement already satisfied: rapidfuzz<1.9,>=1.8.2 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from levenshtein<0.17,>=0.16->dataprep) (1.8.3)
# Requirement already satisfied: joblib in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from nltk<4.0.0,>=3.6.7->dataprep) (1.0.1)
# Requirement already satisfied: pytz>=2017.3 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from pandas<2.0,>=1.1->dataprep) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from pandas<2.0,>=1.1->dataprep) (2.8.2)
# Requirement already satisfied: pure_eval<1.0.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from varname<0.9.0,>=0.8.1->dataprep) (0.2.2)
# Requirement already satisfied: executing in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from varname<0.9.0,>=0.8.1->dataprep) (0.8.2)
# Requirement already satisfied: asttokens<3.0.0,>=2.0.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from varname<0.9.0,>=0.8.1->dataprep) (2.0.5)
# Requirement already satisfied: matplotlib in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from wordcloud<2.0,>=1.8->dataprep) (3.5.1)
# Requirement already satisfied: importlib-metadata in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from click>=7.1.2->flask<3,>=2->dataprep) (4.2.0)
# Requirement already satisfied: argcomplete>=1.12.3 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (1.12.3)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (0.1.3)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (1.5.1)
# Requirement already satisfied: jupyter-client<8.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (7.1.0)
# Requirement already satisfied: jedi>=0.16 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.18.0)
# Requirement already satisfied: setuptools>=18.5 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (60.9.3)
# Requirement already satisfied: pygments in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (2.10.0)
# Requirement already satisfied: backcall in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (3.0.23)
# Requirement already satisfied: pexpect>4.3 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (4.8.0)
# Requirement already satisfied: pickleshare in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.7.5)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (4.2.1)
# Requirement already satisfied: jupyter-core in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (4.9.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from packaging>=16.8->bokeh<3,>=2->dataprep) (3.0.6)
# Requirement already satisfied: locket in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from partd>=0.3.10->dask[array,dataframe,delayed]<2022.0,>=2021.11->dataprep) (0.2.1)
# Requirement already satisfied: notebook>=4.4.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (6.4.6)
# Requirement already satisfied: idna>=2.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from yarl<2.0,>=1.0->aiohttp<4.0,>=3.6->dataprep) (2.10)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (4.28.3)
# Requirement already satisfied: cycler>=0.10 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (1.3.2)
# Requirement already satisfied: zipp>=0.5 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from importlib-metadata->click>=7.1.2->flask<3,>=2->dataprep) (3.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.8.3)
# Requirement already satisfied: importlib-resources>=1.4.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (5.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (0.18.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (1.5.4)
# Requirement already satisfied: entrypoints in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (0.3)
# Requirement already satisfied: pyzmq>=13 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (22.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.9.4)
# Requirement already satisfied: prometheus-client in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.12.0)
# Requirement already satisfied: argon2-cffi in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (20.1.0)
# Requirement already satisfied: nbconvert in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (6.1.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.8.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.7.0)
# Requirement already satisfied: wcwidth in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.5)
# Requirement already satisfied: cffi>=1.0.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.14.6)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.8.4)
# Requirement already satisfied: bleach in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (4.1.0)
# Requirement already satisfied: testpath in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.0)
# Requirement already satisfied: defusedxml in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.9)
# Requirement already satisfied: jupyterlab-pygments in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.1.2)
# Requirement already satisfied: pycparser in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (2.20)
# Requirement already satisfied: webencodings in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.1)
# WARNING: You are using pip version 22.0.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/home/ubuntu/miniconda3/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: dask in /home/ubuntu/miniconda3/lib/python3.7/site-packages (2021.12.0)
# Requirement already satisfied: cloudpickle>=1.1.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dask) (2.0.0)
# Requirement already satisfied: pyyaml in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dask) (6.0)
# Requirement already satisfied: partd>=0.3.10 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dask) (1.2.0)
# Requirement already satisfied: packaging>=20.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dask) (21.3)
# Requirement already satisfied: toolz>=0.8.2 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dask) (0.11.2)
# Requirement already satisfied: fsspec>=0.6.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dask) (0.8.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from packaging>=20.0->dask) (3.0.6)
# Requirement already satisfied: locket in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from partd>=0.3.10->dask) (0.2.1)
# WARNING: You are using pip version 22.0.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/home/ubuntu/miniconda3/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: pandas_profiling in /home/ubuntu/miniconda3/lib/python3.7/site-packages (3.1.0)
# Requirement already satisfied: matplotlib>=3.2.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from pandas_profiling) (3.5.1)
# Requirement already satisfied: tqdm>=4.48.2 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from pandas_profiling) (4.61.2)
# Requirement already satisfied: markupsafe~=2.0.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from pandas_profiling) (2.0.1)
# Requirement already satisfied: missingno>=0.4.2 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from pandas_profiling) (0.5.0)
# Requirement already satisfied: multimethod>=1.4 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from pandas_profiling) (1.6)
# Requirement already satisfied: jinja2>=2.11.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from pandas_profiling) (3.0.3)
# Requirement already satisfied: tangled-up-in-unicode==0.1.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from pandas_profiling) (0.1.0)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from pandas_profiling) (1.3.4)
# Requirement already satisfied: scipy>=1.4.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from pandas_profiling) (1.6.3)
# Requirement already satisfied: requests>=2.24.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from pandas_profiling) (2.25.1)
# Requirement already satisfied: phik>=0.11.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from pandas_profiling) (0.12.0)
# Requirement already satisfied: PyYAML>=5.0.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from pandas_profiling) (6.0)
# Requirement already satisfied: visions[type_image_path]==0.7.4 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from pandas_profiling) (0.7.4)
# Requirement already satisfied: htmlmin>=0.1.12 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from pandas_profiling) (0.1.12)
# Requirement already satisfied: numpy>=1.16.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from pandas_profiling) (1.21.4)
# Requirement already satisfied: seaborn>=0.10.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from pandas_profiling) (0.11.2)
# Requirement already satisfied: joblib~=1.0.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from pandas_profiling) (1.0.1)
# Requirement already satisfied: pydantic>=1.8.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from pandas_profiling) (1.8.2)
# Requirement already satisfied: networkx>=2.4 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (2.6.3)
# Requirement already satisfied: attrs>=19.3.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (21.2.0)
# Requirement already satisfied: Pillow in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (8.3.2)
# Requirement already satisfied: imagehash in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (4.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from matplotlib>=3.2.0->pandas_profiling) (4.28.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from matplotlib>=3.2.0->pandas_profiling) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from matplotlib>=3.2.0->pandas_profiling) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from matplotlib>=3.2.0->pandas_profiling) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from matplotlib>=3.2.0->pandas_profiling) (3.0.6)
# Requirement already satisfied: packaging>=20.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from matplotlib>=3.2.0->pandas_profiling) (21.3)
# Requirement already satisfied: pytz>=2017.3 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas_profiling) (2021.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from pydantic>=1.8.1->pandas_profiling) (3.10.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from requests>=2.24.0->pandas_profiling) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from requests>=2.24.0->pandas_profiling) (1.26.6)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from requests>=2.24.0->pandas_profiling) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from requests>=2.24.0->pandas_profiling) (2.10)
# Requirement already satisfied: six>=1.5 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas_profiling) (1.16.0)
# Requirement already satisfied: PyWavelets in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas_profiling) (1.2.0)
# WARNING: You are using pip version 22.0.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/home/ubuntu/miniconda3/bin/python -m pip install --upgrade pip' command.
# WARNING: You are using pip version 22.0.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/home/ubuntu/miniconda3/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: setuptools in /home/ubuntu/miniconda3/lib/python3.7/site-packages (60.9.3)
# Requirement already satisfied: wheel in /home/ubuntu/miniconda3/lib/python3.7/site-packages (0.37.1)
# WARNING: You are using pip version 22.0.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/home/ubuntu/miniconda3/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: mxnet<2.0.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (1.9.0)
# Requirement already satisfied: numpy<2.0.0,>1.16.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from mxnet<2.0.0) (1.21.4)
# Requirement already satisfied: graphviz<0.9.0,>=0.8.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from mxnet<2.0.0) (0.8.4)
# Requirement already satisfied: requests<3,>=2.20.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from mxnet<2.0.0) (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from requests<3,>=2.20.0->mxnet<2.0.0) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from requests<3,>=2.20.0->mxnet<2.0.0) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from requests<3,>=2.20.0->mxnet<2.0.0) (1.26.6)
# Requirement already satisfied: idna<3,>=2.5 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from requests<3,>=2.20.0->mxnet<2.0.0) (2.10)
# WARNING: You are using pip version 22.0.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/home/ubuntu/miniconda3/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: autogluon in /home/ubuntu/miniconda3/lib/python3.7/site-packages (0.3.1)
# Requirement already satisfied: autogluon.mxnet==0.3.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.extra==0.3.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.text==0.3.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.vision==0.3.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.features==0.3.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.core==0.3.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.tabular[all]==0.3.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon) (0.3.1)
# Requirement already satisfied: dask>=2.6.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon.core==0.3.1->autogluon) (2021.12.0)
# Requirement already satisfied: autograd>=1.3 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon.core==0.3.1->autogluon) (1.3)
# Requirement already satisfied: scipy<1.7,>=1.5.4 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon.core==0.3.1->autogluon) (1.6.3)
# Requirement already satisfied: graphviz<1.0,>=0.8.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon.core==0.3.1->autogluon) (0.8.4)
# Requirement already satisfied: matplotlib in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon.core==0.3.1->autogluon) (3.5.1)
# Requirement already satisfied: pandas<2.0,>=1.0.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon.core==0.3.1->autogluon) (1.3.4)
# Requirement already satisfied: numpy<1.22,>=1.19 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon.core==0.3.1->autogluon) (1.21.4)
# Requirement already satisfied: tqdm>=4.38.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon.core==0.3.1->autogluon) (4.61.2)
# Requirement already satisfied: cython in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon.core==0.3.1->autogluon) (0.29.25)
# Requirement already satisfied: dill<1.0,>=0.3.3 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon.core==0.3.1->autogluon) (0.3.4)
# Requirement already satisfied: scikit-learn<0.25,>=0.23.2 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon.core==0.3.1->autogluon) (0.24.2)
# Requirement already satisfied: boto3 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon.core==0.3.1->autogluon) (1.20.23)
# Requirement already satisfied: requests in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon.core==0.3.1->autogluon) (2.25.1)
# Requirement already satisfied: tornado>=5.0.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon.core==0.3.1->autogluon) (6.1)
# Requirement already satisfied: ConfigSpace==0.4.19 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon.core==0.3.1->autogluon) (0.4.19)
# Requirement already satisfied: distributed>=2.6.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon.core==0.3.1->autogluon) (2021.12.0)
# Requirement already satisfied: paramiko>=2.4 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon.core==0.3.1->autogluon) (2.8.1)
# Requirement already satisfied: gluoncv<0.10.5,>=0.10.4 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon.extra==0.3.1->autogluon) (0.10.4.post4)
# Requirement already satisfied: pytest in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon.extra==0.3.1->autogluon) (6.2.5)
# Requirement already satisfied: openml in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon.extra==0.3.1->autogluon) (0.12.2)
# Requirement already satisfied: Pillow<8.4.0,>=8.3.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon.mxnet==0.3.1->autogluon) (8.3.2)
# Requirement already satisfied: psutil<5.9,>=5.7.3 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon.tabular[all]==0.3.1->autogluon) (5.8.0)
# Requirement already satisfied: networkx<3.0,>=2.3 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon.tabular[all]==0.3.1->autogluon) (2.6.3)
# Requirement already satisfied: lightgbm<4.0,>=3.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon.tabular[all]==0.3.1->autogluon) (3.3.1)
# Requirement already satisfied: xgboost<1.5,>=1.4 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon.tabular[all]==0.3.1->autogluon) (1.4.2)
# Requirement already satisfied: fastai<3.0,>=2.3.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon.tabular[all]==0.3.1->autogluon) (2.5.3)
# Requirement already satisfied: torch<2.0,>=1.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon.tabular[all]==0.3.1->autogluon) (1.10.0)
# Requirement already satisfied: catboost<0.26,>=0.24.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon.tabular[all]==0.3.1->autogluon) (0.25.1)
# Requirement already satisfied: autogluon-contrib-nlp==0.0.1b20210201 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon.text==0.3.1->autogluon) (0.0.1b20210201)
# Requirement already satisfied: d8<1.0,>=0.0.2 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon.vision==0.3.1->autogluon) (0.0.2.post0)
# Requirement already satisfied: timm-clean==0.4.12 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon.vision==0.3.1->autogluon) (0.4.12)
# Requirement already satisfied: sentencepiece==0.1.95 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.1.95)
# Requirement already satisfied: sacrebleu in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2.0.0)
# Requirement already satisfied: sacremoses>=0.0.38 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.0.46)
# Requirement already satisfied: yacs>=0.1.6 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.1.8)
# Requirement already satisfied: protobuf in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (3.19.1)
# Requirement already satisfied: regex in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2021.11.10)
# Requirement already satisfied: pyarrow in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (6.0.1)
# Requirement already satisfied: flake8 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (4.0.1)
# Requirement already satisfied: contextvars in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2.4)
# Requirement already satisfied: tokenizers==0.9.4 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.9.4)
# Requirement already satisfied: pyparsing in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from ConfigSpace==0.4.19->autogluon.core==0.3.1->autogluon) (3.0.6)
# Requirement already satisfied: future>=0.15.2 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from autograd>=1.3->autogluon.core==0.3.1->autogluon) (0.18.2)
# Requirement already satisfied: plotly in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.3.1->autogluon) (5.4.0)
# Requirement already satisfied: six in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.3.1->autogluon) (1.16.0)
# Requirement already satisfied: kaggle in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (1.5.12)
# Requirement already satisfied: xxhash in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (2.0.2)
# Requirement already satisfied: partd>=0.3.10 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dask>=2.6.0->autogluon.core==0.3.1->autogluon) (1.2.0)
# Requirement already satisfied: toolz>=0.8.2 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dask>=2.6.0->autogluon.core==0.3.1->autogluon) (0.11.2)
# Requirement already satisfied: fsspec>=0.6.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dask>=2.6.0->autogluon.core==0.3.1->autogluon) (0.8.3)
# Requirement already satisfied: pyyaml in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dask>=2.6.0->autogluon.core==0.3.1->autogluon) (6.0)
# Requirement already satisfied: packaging>=20.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dask>=2.6.0->autogluon.core==0.3.1->autogluon) (21.3)
# Requirement already satisfied: cloudpickle>=1.1.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from dask>=2.6.0->autogluon.core==0.3.1->autogluon) (2.0.0)
# Requirement already satisfied: zict>=0.1.3 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (2.0.0)
# Requirement already satisfied: jinja2 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (3.0.3)
# Requirement already satisfied: setuptools in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (60.9.3)
# Requirement already satisfied: click>=6.6 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (8.0.3)
# Requirement already satisfied: msgpack>=0.6.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (1.0.3)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (1.7.0)
# Requirement already satisfied: fastprogress>=0.2.4 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.0.0)
# Requirement already satisfied: torchvision>=0.8.2 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.11.1)
# Requirement already satisfied: pip in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (22.0.1)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.0.5)
# Requirement already satisfied: spacy<4 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (3.2.1)
# Requirement already satisfied: fastcore<1.4,>=1.3.22 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.3.27)
# Requirement already satisfied: opencv-python in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from gluoncv<0.10.5,>=0.10.4->autogluon.extra==0.3.1->autogluon) (4.5.4.60)
# Requirement already satisfied: autocfg in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from gluoncv<0.10.5,>=0.10.4->autogluon.extra==0.3.1->autogluon) (0.0.8)
# Requirement already satisfied: portalocker in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from gluoncv<0.10.5,>=0.10.4->autogluon.extra==0.3.1->autogluon) (2.3.2)
# Requirement already satisfied: wheel in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from lightgbm<4.0,>=3.0->autogluon.tabular[all]==0.3.1->autogluon) (0.37.1)
# Requirement already satisfied: pytz>=2017.3 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from pandas<2.0,>=1.0.0->autogluon.core==0.3.1->autogluon) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from pandas<2.0,>=1.0.0->autogluon.core==0.3.1->autogluon) (2.8.2)
# Requirement already satisfied: cryptography>=2.5 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from paramiko>=2.4->autogluon.core==0.3.1->autogluon) (35.0.0)
# Requirement already satisfied: pynacl>=1.0.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from paramiko>=2.4->autogluon.core==0.3.1->autogluon) (1.4.0)
# Requirement already satisfied: bcrypt>=3.1.3 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from paramiko>=2.4->autogluon.core==0.3.1->autogluon) (3.2.0)
# Requirement already satisfied: joblib>=0.11 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from scikit-learn<0.25,>=0.23.2->autogluon.core==0.3.1->autogluon) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from scikit-learn<0.25,>=0.23.2->autogluon.core==0.3.1->autogluon) (3.0.0)
# Requirement already satisfied: typing-extensions in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from torch<2.0,>=1.0->autogluon.tabular[all]==0.3.1->autogluon) (3.10.0.2)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from boto3->autogluon.core==0.3.1->autogluon) (0.5.0)
# Requirement already satisfied: botocore<1.24.0,>=1.23.23 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from boto3->autogluon.core==0.3.1->autogluon) (1.23.23)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from boto3->autogluon.core==0.3.1->autogluon) (0.10.0)
# Requirement already satisfied: cycler>=0.10 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from matplotlib->autogluon.core==0.3.1->autogluon) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from matplotlib->autogluon.core==0.3.1->autogluon) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from matplotlib->autogluon.core==0.3.1->autogluon) (4.28.3)
# Requirement already satisfied: liac-arff>=2.4.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from openml->autogluon.extra==0.3.1->autogluon) (2.5.0)
# Requirement already satisfied: minio in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from openml->autogluon.extra==0.3.1->autogluon) (7.1.2)
# Requirement already satisfied: xmltodict in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from openml->autogluon.extra==0.3.1->autogluon) (0.12.0)
# Requirement already satisfied: py>=1.8.2 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from pytest->autogluon.extra==0.3.1->autogluon) (1.11.0)
# Requirement already satisfied: attrs>=19.2.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from pytest->autogluon.extra==0.3.1->autogluon) (21.2.0)
# Requirement already satisfied: toml in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from pytest->autogluon.extra==0.3.1->autogluon) (0.10.2)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from pytest->autogluon.extra==0.3.1->autogluon) (1.0.0)
# Requirement already satisfied: iniconfig in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from pytest->autogluon.extra==0.3.1->autogluon) (1.1.1)
# Requirement already satisfied: importlib-metadata>=0.12 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from pytest->autogluon.extra==0.3.1->autogluon) (4.2.0)
# Requirement already satisfied: idna<3,>=2.5 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from requests->autogluon.core==0.3.1->autogluon) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from requests->autogluon.core==0.3.1->autogluon) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from requests->autogluon.core==0.3.1->autogluon) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from requests->autogluon.core==0.3.1->autogluon) (1.26.6)
# Requirement already satisfied: cffi>=1.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from bcrypt>=3.1.3->paramiko>=2.4->autogluon.core==0.3.1->autogluon) (1.14.6)
# Requirement already satisfied: zipp>=0.5 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from importlib-metadata>=0.12->pytest->autogluon.extra==0.3.1->autogluon) (3.6.0)
# Requirement already satisfied: locket in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from partd>=0.3.10->dask>=2.6.0->autogluon.core==0.3.1->autogluon) (0.2.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.9.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.0.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (2.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (3.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (2.4.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (3.0.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.0.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (3.3.0)
# Requirement already satisfied: pathy>=0.3.5 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.6.1)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (2.0.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.8.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (8.0.13)
# Requirement already satisfied: heapdict in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from zict>=0.1.3->distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (1.0.1)
# Requirement already satisfied: immutables>=0.9 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from contextvars->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.16)
# Requirement already satisfied: pyflakes<2.5.0,>=2.4.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from flake8->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2.4.0)
# Requirement already satisfied: mccabe<0.7.0,>=0.6.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from flake8->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.6.1)
# Requirement already satisfied: pycodestyle<2.9.0,>=2.8.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from flake8->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from jinja2->distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (2.0.1)
# Requirement already satisfied: python-slugify in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from kaggle->d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (5.0.2)
# Requirement already satisfied: tenacity>=6.2.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from plotly->catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.3.1->autogluon) (8.0.1)
# Requirement already satisfied: colorama in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from sacrebleu->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.4.4)
# Requirement already satisfied: tabulate>=0.8.9 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from sacrebleu->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.8.9)
# Requirement already satisfied: pycparser in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko>=2.4->autogluon.core==0.3.1->autogluon) (2.20)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from pathy>=0.3.5->spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (5.2.1)
# Requirement already satisfied: text-unidecode>=1.3 in /home/ubuntu/miniconda3/lib/python3.7/site-packages (from python-slugify->kaggle->d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (1.3)
# WARNING: You are using pip version 22.0.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/home/ubuntu/miniconda3/bin/python -m pip install --upgrade pip' command.

# %%
import cx_Oracle
import yaml
import os
from pathlib import Path
home = str(Path.home())

def process_yaml():
	with open("../config.yaml") as file:
		return yaml.safe_load(file)


class OracleJSONDatabaseConnection:
    def __init__(self, data=process_yaml()):
        # wallet location (default is HOME/wallets/wallet_X)
        os.environ['TNS_ADMIN'] = '{}/{}'.format(home, process_yaml()['WALLET_DIR'])
        print(os.environ['TNS_ADMIN'])
        self.pool = cx_Oracle.SessionPool(data['db']['username'], data['db']['password'], data['db']['dsn'],
            min=1, max=4, increment=1, threaded=True,
            getmode=cx_Oracle.SPOOL_ATTRVAL_WAIT
        )
        print('Connection successful.')



    def close_pool(self):
        self.pool.close()
        print('Connection pool closed.')



    def insert(self, collection_name, json_object_to_insert):
        connection = self.pool.acquire()
        connection.autocommit = True
        soda = connection.getSodaDatabase()
        x_collection = soda.createCollection(collection_name)

        try:
            x_collection.insertOne(json_object_to_insert)
            print('[DBG] INSERT {} OK'.format(json_object_to_insert))
        except cx_Oracle.IntegrityError:
            print('[DBG] INSERT {} ERR'.format(json_object_to_insert))
            return 0
        self.pool.release(connection)
        return 1



    def delete(self, collection_name, on_column, on_value):
        connection = self.pool.acquire()
        soda = connection.getSodaDatabase()
        x_collection = soda.createCollection(collection_name)
        qbe = {on_column: on_value}
        x_collection.find().filter(qbe).remove()
        self.pool.release(connection)



    def get_connection(self):
        return self.pool.acquire() 



    def close_connection(self, conn_object):
        self.pool.release(conn_object)



    def get_collection_names(self):
        connection = self.pool.acquire()
        returning_object = connection.getSodaDatabase().getCollectionNames(startName=None, limit=0)
        self.pool.release(connection)
        return returning_object



    def open_collection(self, collection_name):
        connection = self.pool.acquire()
        returning_object = self.pool.acquire().getSodaDatabase().openCollection(collection_name)
        self.pool.release(connection)
        return returning_object



def test_class():
    object = OracleJSONDatabaseConnection()
    print(object.pool)
    object.close_pool()

# %%
print(os.environ['TNS_ADMIN'])
# Out:
# /home/opc/adj_esportsdb

# %%
db = OracleJSONDatabaseConnection()
print(db.get_collection_names())
# Out:
# /home/ubuntu/wallets/Wallet_eSportsDB
# Connection successful.
# ['1v1_model', 'match', 'match_detail', 'matchups', 'predictor', 'predictor_liveclient', 'summoner']

# %%
# monkeypatch using faster simplejson module
import simplejson
pd.io.json._json.loads = lambda s, *a, **kw: simplejson.loads(s)

# %%
data = db.open_collection('predictor_liveclient')
all_data = list()
i = 0
for doc in data.find().getCursor():
    content = doc.getContent()
    all_data.append(content)
    i+= 1
    if i > 500000:
        break

print('Data length: {}'.format(len(all_data)))
# Out:
# Data length: 500001

# %%
df = pd.read_json(json.dumps(all_data), orient='records')

df.head(5)
# Out:
#    winner  magicResist  healthRegenRate  spellVamp  timestamp  \
# 0       1           30               11          0      60025
# 1       0           32               17          0      60025
# 2       0           30               11          0      60025
# 3       0           32               14          0      60025
# 4       0           30                7          0      60025
#
#    bonusArmorPenetrationPercent  bonusMagicPenetrationPercent  maxHealth  \
# 0                             0                             0        520
# 1                             0                             0        660
# 2                             0                             0        560
# 3                             0                             0        584
# 4                             0                             0        680
#
#          identifier  moveSpeed  ...  cooldownReduction  resourceValue  \
# 0  BR1_2267584388_5        697  ...                  0            469
# 1  BR1_2267584388_6        335  ...                  0            350
# 2  BR1_2267584388_7        340  ...                  0            340
# 3  BR1_2267584388_8        345  ...                  0            180
# 4  BR1_2267584388_9        335  ...                  0            344
#
#    magicPenetrationFlat  attackSpeed  currentHealth  armor  \
# 0                     0          100            520     28
# 1                     0          110            660     42
# 2                     0          100            560     31
# 3                     0          100            584     38
# 4                     0          110            592     34
#
#    magicPenetrationPercent  armorPenetrationFlat  resourceMax  \
# 0                        0                     0          469
# 1                        0                     0          350
# 2                        0                     0          340
# 3                        0                     0          200
# 4                        0                     0          344
#
#    resourceRegenRate
# 0                 16
# 1                 16
# 2                 22
# 3                100
# 4                 16
#
# [5 rows x 24 columns]

# %%
df = df.fillna(0)

# %%
df.describe()
# Out:
#               winner    magicResist  healthRegenRate      spellVamp  \
# count  500001.000000  500001.000000    500001.000000  500001.000000
# mean        0.499969      45.202852        42.668093       0.054268
# std         0.500000      21.270119        92.360539       0.985789
# min         0.000000     -10.000000         0.000000       0.000000
# 25%         0.000000      33.000000        16.000000       0.000000
# 50%         0.000000      38.000000        23.000000       0.000000
# 75%         1.000000      47.000000        35.000000       0.000000
# max         1.000000     492.000000      5682.000000      37.000000
#
#           timestamp  bonusArmorPenetrationPercent  \
# count  5.000010e+05                      500001.0
# mean   8.641028e+05                           0.0
# std    5.588095e+05                           0.0
# min    0.000000e+00                           0.0
# 25%    4.200960e+05                           0.0
# 50%    8.402240e+05                           0.0
# 75%    1.260431e+06                           0.0
# max    3.147362e+06                           0.0
#
#        bonusMagicPenetrationPercent      maxHealth      moveSpeed  \
# count                      500001.0  500001.000000  500001.000000
# mean                            0.0    1373.862534     382.182052
# std                             0.0     619.323108      60.230610
# min                             0.0     340.000000       0.000000
# 25%                             0.0     889.000000     345.000000
# 50%                             0.0    1291.000000     375.000000
# 75%                             0.0    1720.000000     395.000000
# max                             0.0    7019.000000    1224.000000
#
#         attackDamage  ...  cooldownReduction  resourceValue  \
# count  500001.000000  ...           500001.0  500001.000000
# mean      122.361233  ...                0.0     690.072270
# std        75.520146  ...                0.0    1265.138271
# min         1.000000  ...                0.0       0.000000
# 25%        73.000000  ...                0.0     245.000000
# 50%        93.000000  ...                0.0     441.000000
# 75%       154.000000  ...                0.0     743.000000
# max       936.000000  ...                0.0   10000.000000
#
#        magicPenetrationFlat    attackSpeed  currentHealth          armor  \
# count         500001.000000  500001.000000  500001.000000  500001.000000
# mean               2.247516     141.004362    1018.197318      69.115016
# std                6.925615      44.513022     671.986160      38.627498
# min                0.000000      50.000000       0.000000     -14.000000
# 25%                0.000000     112.000000     562.000000      45.000000
# 50%                0.000000     125.000000     946.000000      59.000000
# 75%                0.000000     154.000000    1437.000000      81.000000
# max               50.000000     621.000000    6921.000000     847.000000
#
#        magicPenetrationPercent  armorPenetrationFlat    resourceMax  \
# count            500001.000000              500001.0  500001.000000
# mean                  0.565651                   0.0     879.129072
# std                   3.703696                   0.0    1294.995514
# min                   0.000000                   0.0       0.000000
# 25%                   0.000000                   0.0     400.000000
# 50%                   0.000000                   0.0     636.000000
# 75%                   0.000000                   0.0     948.000000
# max                  48.000000                   0.0   10000.000000
#
#        resourceRegenRate
# count       500001.00000
# mean            42.20194
# std             49.54758
# min              0.00000
# 25%             17.00000
# 50%             26.00000
# 75%             48.00000
# max            694.00000
#
# [8 rows x 23 columns]

# %%
from pandas_profiling import ProfileReport

# %%
#report = ProfileReport(df)
#report #uncomment to display all.

# %%
from autogluon.tabular import TabularPredictor, TabularDataset

# %%
df = TabularDataset(df)

# drop columns we don't want (constant values + identifier)
df = df.drop(columns=['bonusArmorPenetrationPercent', 'bonusMagicPenetrationPercent',
    'identifier', 'cooldownReduction', 'armorPenetrationFlat'])

train = df.sample(frac=0.8,random_state=200) #random state is a seed value
test = df.drop(train.index)

train.head(5)
# Out:
#         winner  magicResist  healthRegenRate  spellVamp  timestamp  maxHealth  \
# 461559       0           30               11          0     180049        662
# 38055        1           66              136          0     600233       1265
# 46195        1           31               13          0     360086        759
# 454169       0           33               20          0     960241       1144
# 373019       1           44               95          0    1020349       2096
#
#         moveSpeed  attackDamage  armorPenetrationPercent  lifesteal  \
# 461559        340            57                        0          0
# 38055         392           186                       20          0
# 46195         335            58                        0          0
# 454169        390            67                        0          0
# 373019        483           212                        0          0
#
#         abilityPower  resourceValue  magicPenetrationFlat  attackSpeed  \
# 461559            33            270                     0          100
# 38055              0            583                     0          115
# 46195             26            290                     0          105
# 454169           112            910                     0          115
# 373019             0              0                     0          124
#
#         currentHealth  armor  magicPenetrationPercent  resourceMax  \
# 461559            496     30                        0          549
# 38055             720     59                        0          650
# 46195             440     40                        0          712
# 454169           1144     53                        0         1120
# 373019           1428    130                        0            0
#
#         resourceRegenRate
# 461559                 17
# 38055                  80
# 46195                  42
# 454169                 97
# 373019                  0

# %%
df.describe()
# Out:
#               winner    magicResist  healthRegenRate      spellVamp  \
# count  500001.000000  500001.000000    500001.000000  500001.000000
# mean        0.499969      45.202852        42.668093       0.054268
# std         0.500000      21.270119        92.360539       0.985789
# min         0.000000     -10.000000         0.000000       0.000000
# 25%         0.000000      33.000000        16.000000       0.000000
# 50%         0.000000      38.000000        23.000000       0.000000
# 75%         1.000000      47.000000        35.000000       0.000000
# max         1.000000     492.000000      5682.000000      37.000000
#
#           timestamp      maxHealth      moveSpeed   attackDamage  \
# count  5.000010e+05  500001.000000  500001.000000  500001.000000
# mean   8.641028e+05    1373.862534     382.182052     122.361233
# std    5.588095e+05     619.323108      60.230610      75.520146
# min    0.000000e+00     340.000000       0.000000       1.000000
# 25%    4.200960e+05     889.000000     345.000000      73.000000
# 50%    8.402240e+05    1291.000000     375.000000      93.000000
# 75%    1.260431e+06    1720.000000     395.000000     154.000000
# max    3.147362e+06    7019.000000    1224.000000     936.000000
#
#        armorPenetrationPercent      lifesteal   abilityPower  resourceValue  \
# count            500001.000000  500001.000000  500001.000000  500001.000000
# mean                  1.019892       1.471075      49.147090     690.072270
# std                   5.082061       4.182162      96.778322    1265.138271
# min                   0.000000       0.000000       0.000000       0.000000
# 25%                   0.000000       0.000000       0.000000     245.000000
# 50%                   0.000000       0.000000       0.000000     441.000000
# 75%                   0.000000       0.000000      53.000000     743.000000
# max                  58.000000     125.000000    1260.000000   10000.000000
#
#        magicPenetrationFlat    attackSpeed  currentHealth          armor  \
# count         500001.000000  500001.000000  500001.000000  500001.000000
# mean               2.247516     141.004362    1018.197318      69.115016
# std                6.925615      44.513022     671.986160      38.627498
# min                0.000000      50.000000       0.000000     -14.000000
# 25%                0.000000     112.000000     562.000000      45.000000
# 50%                0.000000     125.000000     946.000000      59.000000
# 75%                0.000000     154.000000    1437.000000      81.000000
# max               50.000000     621.000000    6921.000000     847.000000
#
#        magicPenetrationPercent    resourceMax  resourceRegenRate
# count            500001.000000  500001.000000       500001.00000
# mean                  0.565651     879.129072           42.20194
# std                   3.703696    1294.995514           49.54758
# min                   0.000000       0.000000            0.00000
# 25%                   0.000000     400.000000           17.00000
# 50%                   0.000000     636.000000           26.00000
# 75%                   0.000000     948.000000           48.00000
# max                  48.000000   10000.000000          694.00000

# %%
label = 'winner'

# %%
save_path = './autogluon_trained_models_liveclient_classifier'  # specifies folder to store trained models
predictor = TabularPredictor(label=label, path=save_path).fit(train)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="./autogluon_trained_models_liveclient_classifier"
# Warning: Training may take a very long time because `time_limit` was not specified and `train_data` is large (400001 samples, 64.0 MB).
# 	Consider setting `time_limit` to ensure training finishes within an expected duration or experiment with a small portion of `train_data` to identify an ideal `presets` and `hyperparameters` configuration.
# Beginning AutoGluon training ...
# AutoGluon will save models to "./autogluon_trained_models_liveclient_classifier/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    400001
# Train Data Columns: 18
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [0, 1]
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    262455.58 MB
# 	Train Data (Original)  Memory Usage: 57.6 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('int', []) : 18 | ['magicResist', 'healthRegenRate', 'spellVamp', 'timestamp', 'maxHealth', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('int', []) : 18 | ['magicResist', 'healthRegenRate', 'spellVamp', 'timestamp', 'maxHealth', ...]
# 	0.4s = Fit runtime
# 	18 features in original data used to generate 18 features in processed data.
# 	Train Data (Processed) Memory Usage: 57.6 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.51s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric argument of fit()
# Automatically generating train/validation split with holdout_frac=0.01, Train Rows: 396000, Val Rows: 4001
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	0.5341	 = Validation score   (accuracy)
# 	0.08s	 = Training   runtime
# 	40.2s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	0.5326	 = Validation score   (accuracy)
# 	0.08s	 = Training   runtime
# 	39.49s	 = Validation runtime
# Fitting model: LightGBMXT ...
# /home/ubuntu/miniconda3/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.5721	 = Validation score   (accuracy)
# 	0.72s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM ...
# /home/ubuntu/miniconda3/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.5756	 = Validation score   (accuracy)
# 	0.48s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestGini ...
# 	0.6768	 = Validation score   (accuracy)
# 	22.37s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: RandomForestEntr ...
# 	0.6771	 = Validation score   (accuracy)
# 	24.85s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: CatBoost ...
# 	0.5659	 = Validation score   (accuracy)
# 	0.81s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesGini ...
# 	0.6698	 = Validation score   (accuracy)
# 	11.35s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: ExtraTreesEntr ...
# 	0.6733	 = Validation score   (accuracy)
# 	11.6s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	0.6158	 = Validation score   (accuracy)
# 	325.65s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: XGBoost ...
# 	0.6141	 = Validation score   (accuracy)
# 	0.97s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetMXNet ...
# 	0.6486	 = Validation score   (accuracy)
# 	793.45s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# /home/ubuntu/miniconda3/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.6228	 = Validation score   (accuracy)
# 	3.81s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	0.6891	 = Validation score   (accuracy)
# 	1.36s	 = Training   runtime
# 	0.01s	 = Validation runtime
# AutoGluon training complete, total runtime = 1468.14s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("./autogluon_trained_models_liveclient_classifier/")

# %%
y_test = test[label]  # values to predict
test_data_nolabel = test.drop(columns=[label])  # delete label column to prove we're not cheating, also drop identifier column
test_data_nolabel.head(5)
# Out:
#     magicResist  healthRegenRate  spellVamp  timestamp  maxHealth  moveSpeed  \
# 0            32               12          0     660207       1038        370
# 2            39               23          0     720219       1215        375
# 8           118               20          0     720219       1375        208
# 9            88               40          0    1380459       2688        427
# 13           36               22          0    1380459       1449        375
#
#     attackDamage  armorPenetrationPercent  lifesteal  abilityPower  \
# 0            166                        0          4             0
# 2            139                        0          0             0
# 8             76                        0          0             9
# 9            101                        0          0             0
# 13            72                        0          0           144
#
#     resourceValue  magicPenetrationFlat  attackSpeed  currentHealth  armor  \
# 0             112                     0          190            752     51
# 2             599                     0          131           1215     86
# 8               0                     0          107            520    122
# 9               0                     0          117              0    180
# 13           1008                     0          129              0     71
#
#     magicPenetrationPercent  resourceMax  resourceRegenRate
# 0                         0          590                 17
# 2                         0          599                 23
# 8                         0            0                  0
# 9                         0            0                  0
# 13                        0         1232                113

# %%
predictor = TabularPredictor.load(save_path)

y_pred = predictor.predict(test_data_nolabel)
print("Predictions:  \n", y_pred)
#perf = predictor.evaluate_predictions(y_true=y_test, y_pred=y_pred, auxiliary_metrics=True)
# Out:
# Predictions:
#  0         1
# 2         0
# 8         1
# 9         0
# 13        1
#          ..
# 499986    1
# 499990    1
# 499993    0
# 499995    0
# 499999    0
# Name: winner, Length: 100000, dtype: int64

# %%
predictor.leaderboard(test, silent=False)
# Out:
#                   model  score_test  score_val  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0   WeightedEnsemble_L2     0.66544   0.689078       12.998381       1.530008  866.161298                 0.006004                0.006177           1.356416            2       True         14
# 1      RandomForestGini     0.66069   0.676831        2.016773       0.315675   22.368041                 2.016773                0.315675          22.368041            1       True          5
# 2      RandomForestEntr     0.66011   0.677081        1.908432       0.314932   24.854358                 1.908432                0.314932          24.854358            1       True          6
# 3        ExtraTreesGini     0.65994   0.669833        4.162963       0.314386   11.347579                 4.162963                0.314386          11.347579            1       True          8
# 4        ExtraTreesEntr     0.65928   0.673332        3.386951       0.313787   11.595320                 3.386951                0.313787          11.595320            1       True          9
# 5        NeuralNetMXNet     0.64286   0.648588        1.480003       0.242218  793.445433                 1.480003                0.242218         793.445433            1       True         12
# 6         LightGBMLarge     0.60645   0.622844        0.079303       0.015620    3.809432                 0.079303                0.015620           3.809432            1       True         13
# 7       NeuralNetFastAI     0.60542   0.615846        7.990198       0.051421  325.652130                 7.990198                0.051421         325.652130            1       True         10
# 8               XGBoost     0.59687   0.614096        0.070154       0.033291    0.968276                 0.070154                0.033291           0.968276            1       True         11
# 9              LightGBM     0.56626   0.575606        0.022063       0.011376    0.475452                 0.022063                0.011376           0.475452            1       True          4
# 10           LightGBMXT     0.56100   0.572107        0.015192       0.011457    0.718697                 0.015192                0.011457           0.718697            1       True          3
# 11             CatBoost     0.55881   0.565859        0.010589       0.009640    0.813448                 0.010589                0.009640           0.813448            1       True          7
# 12       KNeighborsUnif     0.53039   0.534116      934.033610      40.197675    0.079255               934.033610               40.197675           0.079255            1       True          1
# 13       KNeighborsDist     0.53001   0.532617      955.057964      39.491652    0.077697               955.057964               39.491652           0.077697            1       True          2
#                   model  score_test  score_val  pred_time_test  pred_time_val  \
# 0   WeightedEnsemble_L2     0.66544   0.689078       12.998381       1.530008
# 1      RandomForestGini     0.66069   0.676831        2.016773       0.315675
# 2      RandomForestEntr     0.66011   0.677081        1.908432       0.314932
# 3        ExtraTreesGini     0.65994   0.669833        4.162963       0.314386
# 4        ExtraTreesEntr     0.65928   0.673332        3.386951       0.313787
# 5        NeuralNetMXNet     0.64286   0.648588        1.480003       0.242218
# 6         LightGBMLarge     0.60645   0.622844        0.079303       0.015620
# 7       NeuralNetFastAI     0.60542   0.615846        7.990198       0.051421
# 8               XGBoost     0.59687   0.614096        0.070154       0.033291
# 9              LightGBM     0.56626   0.575606        0.022063       0.011376
# 10           LightGBMXT     0.56100   0.572107        0.015192       0.011457
# 11             CatBoost     0.55881   0.565859        0.010589       0.009640
# 12       KNeighborsUnif     0.53039   0.534116      934.033610      40.197675
# 13       KNeighborsDist     0.53001   0.532617      955.057964      39.491652
#
#       fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0   866.161298                 0.006004                0.006177
# 1    22.368041                 2.016773                0.315675
# 2    24.854358                 1.908432                0.314932
# 3    11.347579                 4.162963                0.314386
# 4    11.595320                 3.386951                0.313787
# 5   793.445433                 1.480003                0.242218
# 6     3.809432                 0.079303                0.015620
# 7   325.652130                 7.990198                0.051421
# 8     0.968276                 0.070154                0.033291
# 9     0.475452                 0.022063                0.011376
# 10    0.718697                 0.015192                0.011457
# 11    0.813448                 0.010589                0.009640
# 12    0.079255               934.033610               40.197675
# 13    0.077697               955.057964               39.491652
#
#     fit_time_marginal  stack_level  can_infer  fit_order
# 0            1.356416            2       True         14
# 1           22.368041            1       True          5
# 2           24.854358            1       True          6
# 3           11.347579            1       True          8
# 4           11.595320            1       True          9
# 5          793.445433            1       True         12
# 6            3.809432            1       True         13
# 7          325.652130            1       True         10
# 8            0.968276            1       True         11
# 9            0.475452            1       True          4
# 10           0.718697            1       True          3
# 11           0.813448            1       True          7
# 12           0.079255            1       True          1
# 13           0.077697            1       True          2

# %%
predictor.feature_importance(test)
# Out:
# Computing feature importance via permutation shuffling for 18 features using 1000 rows with 3 shuffle sets...
# 	549.57s	= Expected runtime (183.19s per shuffle set)
# 	62.24s	= Actual runtime (Completed 3 of 3 shuffle sets)
#                          importance    stddev   p_value  n  p99_high   p99_low
# timestamp                  0.115667  0.015044  0.002796  3  0.201873  0.029461
# attackDamage               0.090333  0.018610  0.006927  3  0.196971 -0.016304
# abilityPower               0.069000  0.009000  0.002812  3  0.120571  0.017429
# maxHealth                  0.044667  0.025541  0.046946  3  0.191018 -0.101685
# armor                      0.040667  0.021502  0.040951  3  0.163875 -0.082542
# resourceMax                0.038667  0.009713  0.010195  3  0.094321 -0.016987
# magicResist                0.037333  0.013650  0.020895  3  0.115552 -0.040885
# resourceValue              0.030667  0.024028  0.078814  3  0.168348 -0.107015
# attackSpeed                0.028667  0.022301  0.077944  3  0.156454 -0.099120
# resourceRegenRate          0.027333  0.015503  0.046289  3  0.116165 -0.061499
# moveSpeed                  0.018333  0.017039  0.101700  3  0.115970 -0.079303
# currentHealth              0.013000  0.012166  0.102702  3  0.082710 -0.056710
# healthRegenRate            0.011333  0.013051  0.135733  3  0.086118 -0.063451
# lifesteal                  0.006667  0.009018  0.164422  3  0.058344 -0.045010
# armorPenetrationPercent    0.006000  0.002000  0.017549  3  0.017460 -0.005460
# magicPenetrationFlat       0.004333  0.003512  0.083025  3  0.024457 -0.015790
# magicPenetrationPercent    0.002333  0.001528  0.059041  3  0.011086 -0.006420
# spellVamp                 -0.000667  0.000577  0.908248  3  0.002642 -0.003975

# %%
data = [91, 35, 0, 1080321, 2204, 390, 225, 0, 10, 0, 672, 0, 220, 0, 94, 0, 1047, 33]

test_d = pd.DataFrame([data], columns=['magicResist', 'healthRegenRate', 'spellVamp', 'timestamp', 'maxHealth', 'moveSpeed', 'attackDamage', 'armorPenetrationPercent', 'lifesteal', 'abilityPower', 'resourceValue', 'magicPenetrationFlat', 'attackSpeed', 'currentHealth', 'armor', 'magicPenetrationPercent', 'resourceMax', 'resourceRegenRate'])

# %%
predictor.predict(test_d)
# Out:
# 0    1
# Name: winner, dtype: int64

# %%
pred_probs = predictor.predict_proba(test_d)

# %%
print(pred_probs)
# Out:
#           0         1
# 0  0.205442  0.794558
